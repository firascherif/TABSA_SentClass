# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
cd drive/My Drive/ABSA-DistilBERT

# %%
# !pip3 install transformers

# %%
# !python3 bert_sentclass.py --num_train_epochs 10 --max_seq_length 512 --batch_size 8

# %% [markdown]
# results/bert_test_ep_7.txt\
# aspect_strict_Acc = 0.7933839479392625\
# aspect_Macro_F1 = 0.8111977907749173\
# aspect_Macro_AUC = 0.9668821168630233\
# sentiment_Acc = 0.9180602006688964\
# sentiment_Macro_AUC = 0.9640063875269755\

# %%
# !python evaluation_sentclass.py --pred_data_dir results/test_ep_7.txt

# %% [markdown]
# results/bert_test_ep_8.txt \
# aspect_strict_Acc = 0.779826464208243 \
# aspect_Macro_F1 = 0.8295651398037447\
# aspect_Macro_AUC = 0.9630456170145626\
# sentiment_Acc = 0.9113712374581939\
# sentiment_Macro_AUC = 0.9621131759660732\

# %%
# !python evaluation_sentclass.py --pred_data_dir results/test_ep_8.txt
